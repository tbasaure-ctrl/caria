# %% [markdown]
# # CARIA Real Data Validation
# ## Validación con Datos Reales usando Financial Modeling Prep API
#
# Este notebook valida el framework CARIA con datos reales de mercado, implementando todas las mejoras críticas:
# - Wavelet decomposition (Morlet CWT)
# - Volatility-normalized entropy
# - Phase-Locking Value (PLV) con validación estricta
# - Surrogate testing (p < 0.01)
# - Validación de hipótesis Super-Criticality
#
# **Autor**: CARIA Research Core
# **Fecha**: Diciembre 2025
# **API**: Financial Modeling Prep (FMP)

# %% [markdown]
# ## 1. Instalación de Dependencias

# %%
# Instalar dependencias necesarias
# !pip install -q PyWavelets pandas numpy scipy scikit-learn requests matplotlib seaborn plotly

# Verificar instalación
import sys
import importlib

required_packages = ['pywt', 'pandas', 'numpy', 'scipy', 'sklearn']
missing = []
for pkg in required_packages:
    try:
        importlib.import_module(pkg)
        print(f"✅ {pkg} instalado")
    except ImportError:
        missing.append(pkg)
        print(f"❌ {pkg} NO instalado")

if missing:
    print(f"\n⚠️ Instalar manualmente: pip install {' '.join(missing)}")

# %% [markdown]
# ## 2. Configuración y Credenciales

# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import requests
import warnings
warnings.filterwarnings('ignore')

# Configuración de FMP API
# IMPORTANTE: Reemplaza con tu API key de FMP
# Obtén una gratis en: https://site.financialmodelingprep.com/developer/docs/
FMP_API_KEY = "TU_API_KEY_AQUI"  # ⚠️ CAMBIAR

FMP_BASE_URL = "https://financialmodelingprep.com/api/v3"

# Símbolos a analizar
SYMBOLS = {
    'SP500': '^GSPC',  # S&P 500
    'BTC': 'BTCUSD',   # Bitcoin (si disponible)
    'VIX': '^VIX',     # VIX
    'TLT': 'TLT',      # Treasury Bonds
    'GLD': 'GLD'       # Gold ETF
}

# Período de análisis
START_DATE = "2010-01-01"
END_DATE = datetime.now().strftime("%Y-%m-%d")

print(f"📅 Período de análisis: {START_DATE} a {END_DATE}")
print(f"📊 Símbolos: {', '.join(SYMBOLS.values())}")
